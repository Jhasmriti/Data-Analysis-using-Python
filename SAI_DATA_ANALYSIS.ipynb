# %% [markdown]
# <a href="https://colab.research.google.com/github/Jhasmriti/Data-Analysis-using-Python/blob/main/SAI_DATA_ANALYSIS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

import pandas as pd

# %%
df =pd.read_excel('/content/SPORTS INFRASTRUCTURE UNDER GIS SYSTEM. (1).xlsx', 'Sheet2',skiprows=1)

# %%
df.head()
# Out:
#    Sl. No.  \
# 0      NaN
# 1      1.0
# 2      2.0
# 3      3.0
# 4      4.0
#
#   Infrastructure available (Stadium, Hall, Swimming Pools and other such facilities Sports-wise)  \
# 0                                                NaN
# 1                            Sri Kanteerava Stadium
# 2                         Koramangala Indoor Stadium
# 3                                       Vidyanagara
# 4                                             Anekal
#
#   Size/ details of Infrastructure                       Unnamed: 3  \
# 0                   Size in Acres                       Survey No.
# 1                     29.36 Acres                    S. No. 193/P1
# 2                      4.16 Acres       S. No. 111, 112, 114, 115,
# 3                     62.00 Acres  S. No. 317, 317/1, 325/1, 325/2
# 4                    10.00  Acres                              248
#
#                                           Unnamed: 4  \
# 0  ¥ÁægÀA¨sÀªÁzÀ ªÀµÀð ªÀÄvÀÄÛ MlÄÖ ªÉZÀÑ (gÀÆ. ®...
# ...

# %%
df.tail()
# Out:
#      Sl. No.  \
# 167    167.0
# 168    168.0
# 169    169.0
# 170    170.0
# 171    171.0
#
#     Infrastructure available (Stadium, Hall, Swimming Pools and other such facilities Sports-wise)  \
# 167                                        Muddebihala
# 168                                            Sindagi
# 169                          Yadagiri district stadium
# 170                                          Shahapura
# 171                                       Gurumithakal
#
#     Size/ details of Infrastructure                  Unnamed: 3  \
# 167                     10.00 Acres                         NaN
# 168                      5.14 Acres                         763
# 169                      39.8 Acres  484, 485, 4865,466,467,468
# 170                     20.00 Acres                         NaN
# 171                     10.00 Acres                         NaN
#
#                  Unnamed: 4  \
# 167                     NaN
# 168                 2011-12
# ...

# %%
df.iloc[10:21]
# Out:
#     Sl. No.  \
# 10     10.0
# 11     11.0
# 12     12.0
# 13     13.0
# 14     14.0
# 15     15.0
# 16     16.0
# 17     17.0
# 18     18.0
# 19     19.0
# 20     20.0
#
#    Infrastructure available (Stadium, Hall, Swimming Pools and other such facilities Sports-wise)  \
# 10                                        Devanahalli
# 11                                     Doddaballapura
# 12            Hosakote (Sri Channabairegowda Stadium)
# 13                                         Nelmangala
# 14                         Bagalakot District Stadium
# 15                                             Bilagi
# 16                                          Hunugunda
# 17                                          Jamakandi
# 18                                            Mudhola
# 19                           Ballari District Stadium
# 20                                    Hoovinahadagali
#
#    Size/ details of Infrastructure                       Unnamed: 3  \
# ...

# %%
df.iloc[20:31]
# Out:
#     Sl. No.  \
# 20     20.0
# 21     21.0
# 22     22.0
# 23     23.0
# 24     24.0
# 25     25.0
# 26     26.0
# 27     27.0
# 28     28.0
# 29     29.0
# 30     30.0
#
#    Infrastructure available (Stadium, Hall, Swimming Pools and other such facilities Sports-wise)  \
# 20                                    Hoovinahadagali
# 21                                             Hospet
# 22                                            Sanduru
# 23                                      Harapanahalli
# 24                           Belgaum District Stadium
# 25                                             Athani
# 26                                       Bailahongala
# 27                                           Chikkodi
# 28                                              Gokak
# 29                                            Hukkeri
# 30                                          Khanapura
#
#    Size/ details of Infrastructure                      Unnamed: 3  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 172 entries, 0 to 171
# Data columns (total 12 columns):
#  #   Column                                                                                          Non-Null Count  Dtype
# ---  ------                                                                                          --------------  -----
#  0   Sl. No.                                                                                         171 non-null    float64
#  1   Infrastructure available (Stadium, Hall, Swimming Pools and other such facilities Sports-wise)  171 non-null    object
#  2   Size/ details of Infrastructure                                                                 168 non-null    object
#  3   Unnamed: 3                                                                                      156 non-null    object
#  4   Unnamed: 4                                                                                      138 non-null    object
# ...

# %%
df.columns
# Out:
# Index(['Sl. No.',
#        'Infrastructure available (Stadium, Hall, Swimming Pools and other such facilities Sports-wise)',
#        'Size/ details of Infrastructure', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Owned by Institution (State Govt./ SAI/Private)',
#        'Built under Scheme',
#        'Location of the Infrastructure (Tehsil/ Taluk and District)',
#        'Details of number of Coaches available for the sport', 'Unnamed: 10',
#        'Unnamed: 11'],
#       dtype='object')

# %%
data=['Size/ details of Infrastructure', 'Unnamed: 3','Unnamed: 4','Unnamed: 5','Owned by Institution (State Govt./ SAI/Private)','Built under Scheme','Details of number of Coaches available for the sport','Details of number of Coaches available for the sport','Unnamed: 10','Unnamed: 11']

# %%
data1=df.drop(data,axis=1,inplace=True)

# %%
df.head()
# Out:
#    Sl. No.  \
# 0      NaN
# 1      1.0
# 2      2.0
# 3      3.0
# 4      4.0
#
#   Infrastructure available (Stadium, Hall, Swimming Pools and other such facilities Sports-wise)  \
# 0                                                NaN
# 1                            Sri Kanteerava Stadium
# 2                         Koramangala Indoor Stadium
# 3                                       Vidyanagara
# 4                                             Anekal
#
#   Location of the Infrastructure (Tehsil/ Taluk and District)
# 0                                                NaN
# 1                                          Bangalore
# 2                                          Bangalore
# 3                                          Bangalore
# 4           Anekal Taluk, Bangalore Urban District.

# %%
df.drop('Sl. No.',axis=1,inplace=True)

# %%
df.head()
# Out:
#   Infrastructure available (Stadium, Hall, Swimming Pools and other such facilities Sports-wise)  \
# 0                                                NaN
# 1                            Sri Kanteerava Stadium
# 2                         Koramangala Indoor Stadium
# 3                                       Vidyanagara
# 4                                             Anekal
#
#   Location of the Infrastructure (Tehsil/ Taluk and District)
# 0                                                NaN
# 1                                          Bangalore
# 2                                          Bangalore
# 3                                          Bangalore
# 4           Anekal Taluk, Bangalore Urban District.

# %%
df.rename(columns={'Infrastructure available (Stadium, Hall, Swimming Pools and other such facilities Sports-wise)':'Name','Location of the Infrastructure (Tehsil/ Taluk and District)':'Address_Line_1'},inplace=True)

# %%
df.head()
# Out:
#                          Name                            Address_Line_1
# 0                         NaN                                       NaN
# 1     Sri Kanteerava Stadium                                  Bangalore
# 2  Koramangala Indoor Stadium                                 Bangalore
# 3                Vidyanagara                                  Bangalore
# 4                      Anekal  Anekal Taluk, Bangalore Urban District.

# %%
df.insert(loc=2,column='district_id', value='0',allow_duplicates=True)

# %%
df.head()
# Out:
#                          Name                            Address_Line_1  \
# 0                         NaN                                       NaN
# 1     Sri Kanteerava Stadium                                  Bangalore
# 2  Koramangala Indoor Stadium                                 Bangalore
# 3                Vidyanagara                                  Bangalore
# 4                      Anekal  Anekal Taluk, Bangalore Urban District.
#
#   district_id
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0

# %%
df.insert(loc=3,column='state_id', value='15',allow_duplicates=True)

# %%
df.head()
# Out:
#                          Name                            Address_Line_1  \
# 0                         NaN                                       NaN
# 1     Sri Kanteerava Stadium                                  Bangalore
# 2  Koramangala Indoor Stadium                                 Bangalore
# 3                Vidyanagara                                  Bangalore
# 4                      Anekal  Anekal Taluk, Bangalore Urban District.
#
#   district_id state_id
# 0           0       15
# 1           0       15
# 2           0       15
# 3           0       15
# 4           0       15

# %%
df.insert(loc=4,column='manager_contact_number', value='01123384782',allow_duplicates=True)

# %%
df.head()
# Out:
#                          Name                            Address_Line_1  \
# 0                         NaN                                       NaN
# 1     Sri Kanteerava Stadium                                  Bangalore
# 2  Koramangala Indoor Stadium                                 Bangalore
# 3                Vidyanagara                                  Bangalore
# 4                      Anekal  Anekal Taluk, Bangalore Urban District.
#
#   district_id state_id manager_contact_number
# 0           0       15            01123384782
# 1           0       15            01123384782
# 2           0       15            01123384782
# 3           0       15            01123384782
# 4           0       15            01123384782

# %%
df.insert(loc=5,column='Name_of_Manager', value='Shri Anurag Thakur',allow_duplicates=True)

# %%
df.head()
# Out:
#                          Name                            Address_Line_1  \
# 0                         NaN                                       NaN
# 1     Sri Kanteerava Stadium                                  Bangalore
# 2  Koramangala Indoor Stadium                                 Bangalore
# 3                Vidyanagara                                  Bangalore
# 4                      Anekal  Anekal Taluk, Bangalore Urban District.
#
#   district_id state_id manager_contact_number     Name_of_Manager
# 0           0       15            01123384782  Shri Anurag Thakur
# 1           0       15            01123384782  Shri Anurag Thakur
# 2           0       15            01123384782  Shri Anurag Thakur
# 3           0       15            01123384782  Shri Anurag Thakur
# 4           0       15            01123384782  Shri Anurag Thakur

# %%
df.insert(loc=6,column='Sub_ownership_id', value='Karnataka',allow_duplicates=True)

# %%
df.head()
# Out:
#                          Name                            Address_Line_1  \
# 0                         NaN                                       NaN
# 1     Sri Kanteerava Stadium                                  Bangalore
# 2  Koramangala Indoor Stadium                                 Bangalore
# 3                Vidyanagara                                  Bangalore
# 4                      Anekal  Anekal Taluk, Bangalore Urban District.
#
#   district_id state_id manager_contact_number     Name_of_Manager  \
# 0           0       15            01123384782  Shri Anurag Thakur
# 1           0       15            01123384782  Shri Anurag Thakur
# 2           0       15            01123384782  Shri Anurag Thakur
# 3           0       15            01123384782  Shri Anurag Thakur
# 4           0       15            01123384782  Shri Anurag Thakur
#
#   Sub_ownership_id
# 0        Karnataka
# 1        Karnataka
# 2        Karnataka
# 3        Karnataka
# 4        Karnataka

# %%
tms =pd.read_excel('/content/pin_code.xlsx')

# %%
tms.head()
# Out:
#    id  district_id  pincode
# 0   1            1   744201
# 1   2            1   744202
# 2   3            2   744302
# 3   4            2   744303
# 4   5            3   744105

# %%
smt =['id','district_id']

# %%
smt1 = tms.drop (smt, axis=1, inplace=True)

# %%
tms.head()
# Out:
#    pincode
# 0   744201
# 1   744202
# 2   744302
# 3   744303
# 4   744105

# %%
data1=pd.concat([df,tms],axis=1)

# %%
data1.head(2)
# Out:
#                       Name Address_Line_1 district_id state_id  \
# 0                      NaN            NaN           0       15
# 1  Sri Kanteerava Stadium       Bangalore           0       15
#
#   manager_contact_number     Name_of_Manager Sub_ownership_id  pincode
# 0            01123384782  Shri Anurag Thakur        Karnataka   744201
# 1            01123384782  Shri Anurag Thakur        Karnataka   744202

# %%
data1.tail()
# Out:
#       Name Address_Line_1 district_id state_id manager_contact_number  \
# 19332  NaN            NaN         NaN      NaN                    NaN
# 19333  NaN            NaN         NaN      NaN                    NaN
# 19334  NaN            NaN         NaN      NaN                    NaN
# 19335  NaN            NaN         NaN      NaN                    NaN
# 19336  NaN            NaN         NaN      NaN                    NaN
#
#       Name_of_Manager Sub_ownership_id  pincode
# 19332             NaN              NaN   835301
# 19333             NaN              NaN   835213
# 19334             NaN              NaN   835203
# 19335             NaN              NaN   835231
# 19336             NaN              NaN   533463

# %%
data1.dropna(inplace = True)

# %%
data1.tail()
# Out:
#                           Name                    Address_Line_1 district_id  \
# 167                Muddebihala  Muddebihal, Vijayapura District.           0
# 168                    Sindagi     Sindagi, Vijayapura District.           0
# 169  Yadagiri district stadium                         Yadagiri.           0
# 170                  Shahapura     Shahapura, Yadagiri District.           0
# 171               Gurumithakal   Gurumitkal, Yadagiri District.            0
#
#     state_id manager_contact_number     Name_of_Manager Sub_ownership_id  \
# 167       15            01123384782  Shri Anurag Thakur        Karnataka
# 168       15            01123384782  Shri Anurag Thakur        Karnataka
# 169       15            01123384782  Shri Anurag Thakur        Karnataka
# 170       15            01123384782  Shri Anurag Thakur        Karnataka
# 171       15            01123384782  Shri Anurag Thakur        Karnataka
#
#      pincode
# 167   524345
# 168   524121
# 169   524408
# ...
